# %%
# %pip install selenium
# %pip install requests
# %pip install pandas
# Out:
# Collecting seleniumNote: you may need to restart the kernel to use updated packages.
#
#   Downloading selenium-4.17.2-py3-none-any.whl.metadata (6.9 kB)
# Collecting urllib3<3,>=1.26 (from urllib3[socks]<3,>=1.26->selenium)
#   Downloading urllib3-2.2.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting trio~=0.17 (from selenium)
#   Downloading trio-0.24.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting trio-websocket~=0.9 (from selenium)
#   Downloading trio_websocket-0.11.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting certifi>=2021.10.8 (from selenium)
#   Downloading certifi-2024.2.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting typing_extensions>=4.9.0 (from selenium)
#   Downloading typing_extensions-4.9.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting attrs>=20.1.0 (from trio~=0.17->selenium)
#   Downloading attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting sortedcontainers (from trio~=0.17->selenium)
#   Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Collecting idna (from trio~=0.17->selenium)
#   Downloading idna-3.6-py3-none-any.whl.metadata (9.9 kB)
# Collecting outcome (from trio~=0.17->selenium)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Collecting sniffio>=1.3.0 (from trio~=0.17->selenium)
#   Downloading sniffio-1.3.0-py3-none-any.whl (10 kB)
# Collecting cffi>=1.14 (from trio~=0.17->selenium)
#   Downloading cffi-1.16.0-cp312-cp312-win_amd64.whl.metadata (1.5 kB)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium)
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Collecting pysocks!=1.5.7,<2.0,>=1.5.6 (from urllib3[socks]<3,>=1.26->selenium)
#   Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Collecting pycparser (from cffi>=1.14->trio~=0.17->selenium)
#   Downloading pycparser-2.21-py2.py3-none-any.whl (118 kB)
#      ---------------------------------------- 0.0/118.7 kB ? eta -:--:--
#      ----------------------- --------------- 71.7/118.7 kB 2.0 MB/s eta 0:00:01
#      -------------------------------------- 118.7/118.7 kB 1.7 MB/s eta 0:00:00
# Collecting h11<1,>=0.9.0 (from wsproto>=0.14->trio-websocket~=0.9->selenium)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ---------------------------------------- 0.0/58.3 kB ? eta -:--:--
#      ----------------------------------- ---- 51.2/58.3 kB 1.3 MB/s eta 0:00:01
#      ---------------------------------------- 58.3/58.3 kB 1.0 MB/s eta 0:00:00
# Downloading selenium-4.17.2-py3-none-any.whl (9.9 MB)
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB 2.0 MB/s eta 0:00:05
#    ---------------------------------------- 0.1/9.9 MB 1.4 MB/s eta 0:00:07
#     --------------------------------------- 0.2/9.9 MB 1.5 MB/s eta 0:00:07
#     --------------------------------------- 0.2/9.9 MB 1.1 MB/s eta 0:00:09
#    - -------------------------------------- 0.3/9.9 MB 1.5 MB/s eta 0:00:07
#    - -------------------------------------- 0.4/9.9 MB 1.6 MB/s eta 0:00:07
#    -- ------------------------------------- 0.5/9.9 MB 1.5 MB/s eta 0:00:07
#    -- ------------------------------------- 0.6/9.9 MB 1.5 MB/s eta 0:00:07
#    -- ------------------------------------- 0.6/9.9 MB 1.5 MB/s eta 0:00:07
#    -- ------------------------------------- 0.7/9.9 MB 1.4 MB/s eta 0:00:07
#    --- ------------------------------------ 0.8/9.9 MB 1.6 MB/s eta 0:00:06
#    --- ------------------------------------ 0.9/9.9 MB 1.5 MB/s eta 0:00:06
#    --- ------------------------------------ 0.9/9.9 MB 1.5 MB/s eta 0:00:06
#    --- ------------------------------------ 0.9/9.9 MB 1.4 MB/s eta 0:00:07
#    ---- ----------------------------------- 1.0/9.9 MB 1.4 MB/s eta 0:00:07
#    ---- ----------------------------------- 1.0/9.9 MB 1.4 MB/s eta 0:00:07
#    ---- ----------------------------------- 1.1/9.9 MB 1.3 MB/s eta 0:00:07
#    ---- ----------------------------------- 1.2/9.9 MB 1.3 MB/s eta 0:00:07
#    ---- ----------------------------------- 1.2/9.9 MB 1.4 MB/s eta 0:00:07
#    ----- ---------------------------------- 1.2/9.9 MB 1.3 MB/s eta 0:00:07
#    ----- ---------------------------------- 1.3/9.9 MB 1.3 MB/s eta 0:00:07
#    ----- ---------------------------------- 1.3/9.9 MB 1.2 MB/s eta 0:00:07
#    ----- ---------------------------------- 1.3/9.9 MB 1.2 MB/s eta 0:00:07
#    ----- ---------------------------------- 1.4/9.9 MB 1.2 MB/s eta 0:00:07
#    ------ --------------------------------- 1.5/9.9 MB 1.2 MB/s eta 0:00:07
#    ------ --------------------------------- 1.5/9.9 MB 1.2 MB/s eta 0:00:07
#    ------ --------------------------------- 1.6/9.9 MB 1.2 MB/s eta 0:00:07
#    ------ --------------------------------- 1.6/9.9 MB 1.2 MB/s eta 0:00:07
#    ------ --------------------------------- 1.7/9.9 MB 1.2 MB/s eta 0:00:07
#    ------ --------------------------------- 1.7/9.9 MB 1.2 MB/s eta 0:00:07
#    ------- -------------------------------- 1.8/9.9 MB 1.2 MB/s eta 0:00:07
#    ------- -------------------------------- 1.9/9.9 MB 1.2 MB/s eta 0:00:07
#    -------- ------------------------------- 2.0/9.9 MB 1.3 MB/s eta 0:00:07
#    -------- ------------------------------- 2.2/9.9 MB 1.3 MB/s eta 0:00:06
#    --------- ------------------------------ 2.4/9.9 MB 1.4 MB/s eta 0:00:06
#    --------- ------------------------------ 2.4/9.9 MB 1.4 MB/s eta 0:00:06
#    ---------- ----------------------------- 2.7/9.9 MB 1.5 MB/s eta 0:00:05
#    ------------ --------------------------- 3.0/9.9 MB 1.6 MB/s eta 0:00:05
#    ------------- -------------------------- 3.2/9.9 MB 1.7 MB/s eta 0:00:04
#    -------------- ------------------------- 3.5/9.9 MB 1.8 MB/s eta 0:00:04
#    --------------- ------------------------ 3.8/9.9 MB 1.9 MB/s eta 0:00:04
#    ---------------- ----------------------- 4.0/9.9 MB 1.9 MB/s eta 0:00:04
#    ----------------- ---------------------- 4.2/9.9 MB 2.0 MB/s eta 0:00:03
#    ----------------- ---------------------- 4.4/9.9 MB 2.0 MB/s eta 0:00:03
#    ----------------- ---------------------- 4.4/9.9 MB 2.0 MB/s eta 0:00:03
#    ------------------ --------------------- 4.5/9.9 MB 2.0 MB/s eta 0:00:03
#    ------------------ --------------------- 4.5/9.9 MB 2.0 MB/s eta 0:00:03
#    ------------------ --------------------- 4.6/9.9 MB 2.0 MB/s eta 0:00:03
#    ------------------ --------------------- 4.6/9.9 MB 2.0 MB/s eta 0:00:03
#    -------------------- ------------------- 5.1/9.9 MB 2.1 MB/s eta 0:00:03
#    --------------------- ------------------ 5.2/9.9 MB 2.1 MB/s eta 0:00:03
#    ---------------------- ----------------- 5.5/9.9 MB 2.2 MB/s eta 0:00:03
#    ----------------------- ---------------- 5.8/9.9 MB 2.3 MB/s eta 0:00:02
#    ------------------------ --------------- 6.0/9.9 MB 2.3 MB/s eta 0:00:02
#    ------------------------ --------------- 6.1/9.9 MB 2.3 MB/s eta 0:00:02
#    ------------------------ --------------- 6.1/9.9 MB 2.2 MB/s eta 0:00:02
#    ------------------------- -------------- 6.2/9.9 MB 2.2 MB/s eta 0:00:02
#    ------------------------- -------------- 6.3/9.9 MB 2.3 MB/s eta 0:00:02
#    -------------------------- ------------- 6.5/9.9 MB 2.3 MB/s eta 0:00:02
#    --------------------------- ------------ 6.8/9.9 MB 2.3 MB/s eta 0:00:02
#    --------------------------- ------------ 6.9/9.9 MB 2.3 MB/s eta 0:00:02
#    ---------------------------- ----------- 7.0/9.9 MB 2.3 MB/s eta 0:00:02
#    ---------------------------- ----------- 7.1/9.9 MB 2.3 MB/s eta 0:00:02
#    ----------------------------- ---------- 7.3/9.9 MB 2.4 MB/s eta 0:00:02
#    ------------------------------ --------- 7.5/9.9 MB 2.4 MB/s eta 0:00:01
#    ------------------------------- -------- 7.9/9.9 MB 2.4 MB/s eta 0:00:01
#    -------------------------------- ------- 8.1/9.9 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.4/9.9 MB 2.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.7/9.9 MB 2.6 MB/s eta 0:00:01
#    ------------------------------------ --- 9.0/9.9 MB 2.6 MB/s eta 0:00:01
#    ------------------------------------- -- 9.3/9.9 MB 2.7 MB/s eta 0:00:01
#    -------------------------------------- - 9.6/9.9 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------  9.9/9.9 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------------  9.9/9.9 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 2.7 MB/s eta 0:00:00
# Downloading certifi-2024.2.2-py3-none-any.whl (163 kB)
#    ---------------------------------------- 0.0/163.8 kB ? eta -:--:--
#    ---------------------------------------- 163.8/163.8 kB 5.0 MB/s eta 0:00:00
# Downloading trio-0.24.0-py3-none-any.whl (460 kB)
#    ---------------------------------------- 0.0/460.2 kB ? eta -:--:--
#    -------------------------- ------------- 307.2/460.2 kB 9.6 MB/s eta 0:00:01
#    ---------------------------------------- 460.2/460.2 kB 5.8 MB/s eta 0:00:00
# Downloading trio_websocket-0.11.1-py3-none-any.whl (17 kB)
# Downloading typing_extensions-4.9.0-py3-none-any.whl (32 kB)
# Downloading urllib3-2.2.0-py3-none-any.whl (120 kB)
#    ---------------------------------------- 0.0/120.9 kB ? eta -:--:--
#    ---------------------------------------- 120.9/120.9 kB 6.9 MB/s eta 0:00:00
# Downloading attrs-23.2.0-py3-none-any.whl (60 kB)
#    ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#    ---------------------------------------- 60.8/60.8 kB 3.2 MB/s eta 0:00:00
# Downloading cffi-1.16.0-cp312-cp312-win_amd64.whl (181 kB)
#    ---------------------------------------- 0.0/182.0 kB ? eta -:--:--
#    --------------------------------------- 182.0/182.0 kB 10.7 MB/s eta 0:00:00
# Downloading idna-3.6-py3-none-any.whl (61 kB)
#    ---------------------------------------- 0.0/61.6 kB ? eta -:--:--
#    ---------------------------------------- 61.6/61.6 kB 3.4 MB/s eta 0:00:00
# Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Installing collected packages: sortedcontainers, urllib3, typing_extensions, sniffio, pysocks, pycparser, idna, h11, certifi, attrs, wsproto, outcome, cffi, trio, trio-websocket, selenium
# Successfully installed attrs-23.2.0 certifi-2024.2.2 cffi-1.16.0 h11-0.14.0 idna-3.6 outcome-1.3.0.post0 pycparser-2.21 pysocks-1.7.1 selenium-4.17.2 sniffio-1.3.0 sortedcontainers-2.4.0 trio-0.24.0 trio-websocket-0.11.1 typing_extensions-4.9.0 urllib3-2.2.0 wsproto-1.2.0
# Collecting requests
#   Downloading requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting charset-normalizer<4,>=2 (from requests)
#   Downloading charset_normalizer-3.3.2-cp312-cp312-win_amd64.whl.metadata (34 kB)
# Requirement already satisfied: idna<4,>=2.5 in c:\python312\lib\site-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\python312\lib\site-packages (from requests) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python312\lib\site-packages (from requests) (2024.2.2)
# Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#    ---------------------------------------- 0.0/62.6 kB ? eta -:--:--
#    ------------------- -------------------- 30.7/62.6 kB ? eta -:--:--
#    ---------------------------------------- 62.6/62.6 kB 670.9 kB/s eta 0:00:00
# Downloading charset_normalizer-3.3.2-cp312-cp312-win_amd64.whl (100 kB)
#    ---------------------------------------- 0.0/100.4 kB ? eta -:--:--
#    ---------------------------------------- 100.4/100.4 kB 1.9 MB/s eta 0:00:00
# Installing collected packages: charset-normalizer, requests
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to write executable - trying to use .deleteme logic
# ERROR: Could not install packages due to an OSError: [WinError 2] The system cannot find the file specified: 'c:\\Python312\\Scripts\\normalizer.exe' -> 'c:\\Python312\\Scripts\\normalizer.exe.deleteme'
# Collecting pandas
#   Downloading pandas-2.2.0-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Collecting numpy<2,>=1.26.0 (from pandas)
#   Downloading numpy-1.26.4-cp312-cp312-win_amd64.whl.metadata (61 kB)
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/61.0 kB ? eta -:--:--
#      ------------------------- ------------ 41.0/61.0 kB 653.6 kB/s eta 0:00:01
#      -------------------------------------- 61.0/61.0 kB 819.4 kB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\nguye\appdata\roaming\python\python312\site-packages (from pandas) (2.8.2)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\nguye\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading pandas-2.2.0-cp312-cp312-win_amd64.whl (11.5 MB)
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#     --------------------------------------- 0.1/11.5 MB 2.8 MB/s eta 0:00:04
#    - -------------------------------------- 0.5/11.5 MB 4.7 MB/s eta 0:00:03
#    --- ------------------------------------ 0.9/11.5 MB 6.2 MB/s eta 0:00:02
#    --- ------------------------------------ 1.0/11.5 MB 6.1 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.4/11.5 MB 6.1 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.6/11.5 MB 6.3 MB/s eta 0:00:02
#    ------ --------------------------------- 2.0/11.5 MB 6.2 MB/s eta 0:00:02
#    ------- -------------------------------- 2.2/11.5 MB 6.2 MB/s eta 0:00:02
#    -------- ------------------------------- 2.4/11.5 MB 6.2 MB/s eta 0:00:02
#    --------- ------------------------------ 2.8/11.5 MB 6.4 MB/s eta 0:00:02
#    ----------- ---------------------------- 3.2/11.5 MB 6.7 MB/s eta 0:00:02
#    ------------ --------------------------- 3.6/11.5 MB 7.0 MB/s eta 0:00:02
#    ------------- -------------------------- 4.0/11.5 MB 7.0 MB/s eta 0:00:02
#    ---------------- ----------------------- 4.6/11.5 MB 7.6 MB/s eta 0:00:01
#    ---------------- ----------------------- 4.8/11.5 MB 7.1 MB/s eta 0:00:01
#    ------------------- -------------------- 5.5/11.5 MB 7.7 MB/s eta 0:00:01
#    ------------------- -------------------- 5.6/11.5 MB 7.7 MB/s eta 0:00:01
#    -------------------- ------------------- 6.0/11.5 MB 7.5 MB/s eta 0:00:01
#    ---------------------- ----------------- 6.4/11.5 MB 7.7 MB/s eta 0:00:01
#    ----------------------- ---------------- 6.8/11.5 MB 7.7 MB/s eta 0:00:01
#    ------------------------- -------------- 7.3/11.5 MB 7.8 MB/s eta 0:00:01
#    -------------------------- ------------- 7.6/11.5 MB 7.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 8.2/11.5 MB 7.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.4/11.5 MB 7.9 MB/s eta 0:00:01
#    ------------------------------ --------- 8.8/11.5 MB 7.7 MB/s eta 0:00:01
#    --------------------------------- ------ 9.5/11.5 MB 7.9 MB/s eta 0:00:01
#    --------------------------------- ------ 9.6/11.5 MB 7.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 10.0/11.5 MB 7.8 MB/s eta 0:00:01
#    ------------------------------------- -- 10.6/11.5 MB 8.3 MB/s eta 0:00:01
#    ------------------------------------- -- 10.9/11.5 MB 8.2 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 8.5 MB/s eta 0:00:01
#    ---------------------------------------- 11.5/11.5 MB 8.3 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp312-cp312-win_amd64.whl (15.5 MB)
#    ---------------------------------------- 0.0/15.5 MB ? eta -:--:--
#    - -------------------------------------- 0.6/15.5 MB 11.8 MB/s eta 0:00:02
#    --- ------------------------------------ 1.2/15.5 MB 12.6 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.6/15.5 MB 12.9 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.9/15.5 MB 10.1 MB/s eta 0:00:02
#    ------ --------------------------------- 2.4/15.5 MB 10.0 MB/s eta 0:00:02
#    ------- -------------------------------- 2.9/15.5 MB 10.2 MB/s eta 0:00:02
#    -------- ------------------------------- 3.3/15.5 MB 10.4 MB/s eta 0:00:02
#    --------- ------------------------------ 3.6/15.5 MB 9.7 MB/s eta 0:00:02
#    ----------- ---------------------------- 4.3/15.5 MB 9.7 MB/s eta 0:00:02
#    ----------- ---------------------------- 4.5/15.5 MB 9.7 MB/s eta 0:00:02
#    ------------ --------------------------- 5.0/15.5 MB 9.7 MB/s eta 0:00:02
#    -------------- ------------------------- 5.4/15.5 MB 9.9 MB/s eta 0:00:02
#    -------------- ------------------------- 5.7/15.5 MB 9.9 MB/s eta 0:00:01
#    --------------- ------------------------ 6.1/15.5 MB 9.5 MB/s eta 0:00:01
#    ---------------- ----------------------- 6.3/15.5 MB 9.0 MB/s eta 0:00:02
#    ----------------- ---------------------- 6.8/15.5 MB 9.3 MB/s eta 0:00:01
#    ------------------ --------------------- 7.3/15.5 MB 9.2 MB/s eta 0:00:01
#    -------------------- ------------------- 8.0/15.5 MB 9.5 MB/s eta 0:00:01
#    -------------------- ------------------- 8.1/15.5 MB 9.4 MB/s eta 0:00:01
#    ---------------------- ----------------- 8.8/15.5 MB 9.2 MB/s eta 0:00:01
#    ------------------------ --------------- 9.4/15.5 MB 9.4 MB/s eta 0:00:01
#    ------------------------- -------------- 9.9/15.5 MB 9.5 MB/s eta 0:00:01
#    -------------------------- ------------- 10.1/15.5 MB 9.2 MB/s eta 0:00:01
#    --------------------------- ------------ 10.6/15.5 MB 9.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 11.2/15.5 MB 9.2 MB/s eta 0:00:01
#    ------------------------------ --------- 11.7/15.5 MB 9.2 MB/s eta 0:00:01
#    ------------------------------- -------- 12.3/15.5 MB 9.8 MB/s eta 0:00:01
#    --------------------------------- ------ 12.8/15.5 MB 9.8 MB/s eta 0:00:01
#    --------------------------------- ------ 13.0/15.5 MB 9.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 13.5/15.5 MB 9.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 13.9/15.5 MB 9.6 MB/s eta 0:00:01
#    ------------------------------------ --- 14.3/15.5 MB 9.4 MB/s eta 0:00:01
#    -------------------------------------- - 14.9/15.5 MB 9.5 MB/s eta 0:00:01
#    ---------------------------------------  15.2/15.5 MB 9.4 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.5 MB 9.4 MB/s eta 0:00:01
#    ---------------------------------------- 15.5/15.5 MB 9.0 MB/s eta 0:00:00
# Downloading pytz-2024.1-py2.py3-none-any.whl (505 kB)
#    ---------------------------------------- 0.0/505.5 kB ? eta -:--:--
#    --------------------------------------  501.8/505.5 kB 15.9 MB/s eta 0:00:01
#    --------------------------------------- 505.5/505.5 kB 10.5 MB/s eta 0:00:00
# Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#    ---------------------------------------- 0.0/345.4 kB ? eta -:--:--
#    --------------------------------------  337.9/345.4 kB 10.2 MB/s eta 0:00:01
#    ---------------------------------------- 345.4/345.4 kB 5.3 MB/s eta 0:00:00
# Installing collected packages: pytz, tzdata, numpy, pandas
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to write executable - trying to use .deleteme logic
# ERROR: Could not install packages due to an OSError: [WinError 2] The system cannot find the file specified: 'c:\\Python312\\Scripts\\f2py.exe' -> 'c:\\Python312\\Scripts\\f2py.exe.deleteme'

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
import requests as rq
import re
import pandas as pd
import os
import pathlib
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_15328\548953211.py:8: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
#cấu hình chrome driver
#config chrome driver options for crawl images
chrome_options = Options()
chrome_options.add_argument("--headless")
chrome_options.add_argument("--disable-gpu")
chrome_options.add_argument("--no-sandbox")
chrome_options.add_argument("--disable-dev-shm-usage")
chrome_options.add_argument("--disable-extensions")

# %%
#khởi tạo driver
driver = webdriver.Chrome(options=chrome_options)

# %%
# URL to the dermnet website
url = "https://dermnetnz.org/image-library"

# Navigating to the specified url in chrome
driver.get(url)
driver.implicitly_wait(5)

# %%
# Finding all the skin_disorders listed on the main page
skin_disorder_tag_main_page = driver.find_elements("xpath", '//a[@class="imageList__group__item"]')

# For loop to extract the skin disorder names and the link to the skin_disorders
disorder_names = []
link_list= []
for tag in skin_disorder_tag_main_page:
    disorder_names.append(tag.text)
    link_list.append(tag.get_attribute("href"))

# Previewing the lists created:
print(f'The first 10 skin condition names: \n {disorder_names[:10]}\n')
print(f'The first 10 links to skin condition image links:\n{link_list[:10]}')
# Out:
# The first 10 skin condition names:
#  ['Acne affecting the back images', 'Acne affecting the face images', 'Acne and other follicular disorder images', 'Acquired dermal macular hyperpigmentation images', 'Acral lentiginous melanoma images', 'Actinic keratosis affecting the face images', 'Actinic keratosis affecting the hand images', 'Actinic keratosis affecting the legs and feet images', 'Actinic keratosis affecting the scalp images', 'Actinic keratosis dermoscopy images']
#
# The first 10 links to skin condition image links:
# ['https://dermnetnz.org/topics/acne-affecting-the-back-images', 'https://dermnetnz.org/topics/acne-face-images', 'https://dermnetnz.org/image-catalogue/acne-and-other-follicular-disorder-images', 'https://dermnetnz.org/topics/acquired-dermal-macular-hyperpigmentation-images', 'https://dermnetnz.org/images/acral-lentiginous-melanoma-images', 'https://dermnetnz.org/topics/actinic-keratosis-face-images', 'https://dermnetnz.org/topics/actinic-keratosis-affecting-the-hand-images', 'https://dermnetnz.org/topics/actinic-keratosis-leg-and-foot-images', 'https://dermnetnz.org/topics/actinic-keratosis-scalp-images', 'https://dermnetnz.org/topics/actinic-keratosis-dermoscopy-images']

# %%
# The number of skin_disorders listed in the website
print(f'The are {len(disorder_names)} skin conditions listed in the DermNet website.')
# Out:
# The are 294 skin conditions listed in the DermNet website.

# %%
# Creating a dataframe with two columns, the skin_disorder names and the links to the images of the skin disorders
name_link_df = pd.DataFrame({'skin_disorder_name': disorder_names, 'link': link_list})

# Saving the dataframe as a csv file
name_link_df.to_csv('Data/name_link.csv', index=False)

# Previewing the first five rows of the dataframe
name_link_df.head()
# Out:
#                                  skin_disorder_name  \
# 0                    Acne affecting the back images
# 1                    Acne affecting the face images
# 2         Acne and other follicular disorder images
# 3  Acquired dermal macular hyperpigmentation images
# 4                 Acral lentiginous melanoma images
#
#                                                 link
# 0  https://dermnetnz.org/topics/acne-affecting-th...
# 1      https://dermnetnz.org/topics/acne-face-images
# 2  https://dermnetnz.org/image-catalogue/acne-and...
# 3  https://dermnetnz.org/topics/acquired-dermal-m...
# 4  https://dermnetnz.org/images/acral-lentiginous...

# %%
# create an empty list to store the url for each link/disease pair
image_disease = []
list_disease_name=[]

# loop through each link/disease pair
for link, disease_name in zip(link_list, disorder_names):
    # create an empty list to store the image URLs
    driver = webdriver.Chrome(options=chrome_options)
    try:
        # navigate to the link
        driver.get(link)
        print(f"extract {link}...")
        # wait for the page to load
        time.sleep(5)
        # find all the elements on the page with the class "imageLinkBlock__item__image"
        skin_image_disorder = driver.find_elements("xpath", '//div[@class="imageLinkBlock__item__image"]/img')
        # loop through each element and find all the images within it
        for image in skin_image_disorder:
            # add each image URL to the image_disease list
            image_disease.append(image.get_attribute("src"))
            list_disease_name.append(disease_name)
    except Exception as e:
        # if an error occurs, print the error message and move to the next link/disease pair
        print(f"Error occurred for {disease_name}: {str(e)}")
        continue
    finally:
        driver.quit()
# Out:
# extract https://dermnetnz.org/topics/acne-affecting-the-back-images...
# extract https://dermnetnz.org/topics/acne-face-images...
# extract https://dermnetnz.org/image-catalogue/acne-and-other-follicular-disorder-images...
# extract https://dermnetnz.org/topics/acquired-dermal-macular-hyperpigmentation-images...
# extract https://dermnetnz.org/images/acral-lentiginous-melanoma-images...
# extract https://dermnetnz.org/topics/actinic-keratosis-face-images...
# extract https://dermnetnz.org/topics/actinic-keratosis-affecting-the-hand-images...
# extract https://dermnetnz.org/topics/actinic-keratosis-leg-and-foot-images...
# extract https://dermnetnz.org/topics/actinic-keratosis-scalp-images...
# extract https://dermnetnz.org/topics/actinic-keratosis-dermoscopy-images...
# extract https://dermnetnz.org/topics/actinic-keratosis-on-the-nose-images...
# extract https://dermnetnz.org/topics/actinic-keratosis-imiquimod-images...
# extract https://dermnetnz.org/topics/adalimumab-images...
# extract https://dermnetnz.org/images/alopecia-areata-images...
# extract https://dermnetnz.org/images/amelanotic-melanoma-images...
# extract https://dermnetnz.org/topics/anal-cancer-images...
# extract https://dermnetnz.org/topics/angiofibromas-images...
# extract https://dermnetnz.org/topics/angiokeratoma-images...
# extract https://dermnetnz.org/images/angular-cheilitis-images...
# extract https://dermnetnz.org/image-catalogue/insect-mite-and-worm-bite-images...
# extract https://dermnetnz.org/images/atopic-dermatitis-images...
# extract https://dermnetnz.org/images/atopic-dermatitis-images...
# extract https://dermnetnz.org/topics/atopic-flexural-eczema-images...
# extract https://dermnetnz.org/topics/atypical-naevus-images...
# extract https://dermnetnz.org/topics/atypical-mycobacterial-infection-images...
# extract https://dermnetnz.org/topics/atypical-naevus-images...
# extract https://dermnetnz.org/images/alopecia-areata-images...
# extract https://dermnetnz.org/topics/atypical-naevus-images...
# extract https://dermnetnz.org/topics/basal-cell-carcinoma-affecting-the-ear-images...
# extract https://dermnetnz.org/topics/basal-cell-carcinoma-affecting-the-eyelid-images...
# extract https://dermnetnz.org/topics/basal-cell-carcinoma-affecting-the-face-images...
# extract https://dermnetnz.org/topics/basal-cell-carcinoma-affecting-the-nose-images...
# extract https://dermnetnz.org/topics/basal-cell-carcinoma-affecting-the-trunk-images...
# extract https://dermnetnz.org/image-catalogue/bacterial-skin-infection-images...
# extract https://dermnetnz.org/image-catalogue/bacterial-skin-infection-images...
# extract https://dermnetnz.org/topics/balanitis-images...
# extract https://dermnetnz.org/topics/basal-cell-carcinoma-affecting-the-ear-images...
# extract https://dermnetnz.org/topics/basal-cell-carcinoma-affecting-the-eyelid-images...
# extract https://dermnetnz.org/topics/basal-cell-carcinoma-affecting-the-face-images...
# extract https://dermnetnz.org/topics/basal-cell-carcinoma-affecting-the-nose-images...
# extract https://dermnetnz.org/topics/basal-cell-carcinoma-affecting-the-trunk-images...
# extract https://dermnetnz.org/topics/basal-cell-carcinoma-affecting-the-ear-images...
# extract https://dermnetnz.org/topics/basal-cell-carcinoma-affecting-the-eyelid-images...
# extract https://dermnetnz.org/topics/basal-cell-carcinoma-affecting-the-face-images...
# extract https://dermnetnz.org/topics/basal-cell-carcinoma-affecting-the-nose-images...
# extract https://dermnetnz.org/topics/basal-cell-carcinoma-affecting-the-trunk-images...
# extract https://dermnetnz.org/topics/basal-cell-carcinoma-affecting-the-ear-images...
# extract https://dermnetnz.org/topics/basal-cell-carcinoma-affecting-the-eyelid-images...
# extract https://dermnetnz.org/topics/basal-cell-carcinoma-affecting-the-face-images...
# extract https://dermnetnz.org/topics/basal-cell-carcinoma-affecting-the-nose-images...
# extract https://dermnetnz.org/topics/basal-cell-carcinoma-affecting-the-trunk-images...
# extract https://dermnetnz.org/images/behcet-disease-images...
# extract https://dermnetnz.org/images/atopic-dermatitis-images...
# extract https://dermnetnz.org/topics/bowenoid-papulosis-images...
# extract https://dermnetnz.org/topics/bullous-pemphigoid-images...
# extract https://dermnetnz.org/images/covid-19-images...
# extract https://dermnetnz.org/topics/candida-affecting-the-lips-mouth-and-face-images...
# extract https://dermnetnz.org/images/onychomycosis-images...
# extract https://dermnetnz.org/topics/candida-intertrigo-images...
# extract https://dermnetnz.org/topics/candida-vulvovaginitis-images...
# extract https://dermnetnz.org/topics/candida-affecting-the-lips-mouth-and-face-images...
# extract https://dermnetnz.org/topics/candida-affecting-the-lips-mouth-and-face-images...
# extract https://dermnetnz.org/topics/capillaritis-images...
# extract https://dermnetnz.org/topics/cherry-angioma-images...
# extract https://dermnetnz.org/topics/chronic-plaque-psoriasis-images...
# extract https://dermnetnz.org/topics/atypical-naevus-images...
# extract https://dermnetnz.org/topics/corn-clavus-images...
# extract https://dermnetnz.org/topics/conditions-affecting-the-ear-images...
# extract https://dermnetnz.org/topics/contact-allergic-dermatitis-of-the-arm-and-leg-images...
# extract https://dermnetnz.org/topics/contact-allergic-dermatitis-of-the-face-images...
# extract https://dermnetnz.org/topics/contact-allergic-dermatitis-of-the-hand-images...
# extract https://dermnetnz.org/topics/contact-allergic-dermatitis-of-the-torso-images...
# extract https://dermnetnz.org/topics/contact-irritant-dermatitis-images...
# extract https://dermnetnz.org/topics/corn-clavus-images...
# extract https://dermnetnz.org/topics/cutaneous-horn-images...
# extract https://dermnetnz.org/topics/cutaneous-lupus-erythematosus-images...
# extract https://dermnetnz.org/topics/cutaneous-tuberculosis-images...
# extract https://dermnetnz.org/...
# extract https://dermnetnz.org/image-catalogue/deep-dermal-disorder-images...
# extract https://dermnetnz.org/images/atopic-dermatitis-images...
# extract https://dermnetnz.org/topics/dermatofibroma-images...
# extract https://dermnetnz.org/topics/dermatomyositis-images...
# extract https://dermnetnz.org/topics/dermographism-images...
# extract https://dermnetnz.org/image-catalogue/dermoscopy-course-images...
# extract https://dermnetnz.org/topics/digital-myxoid-cyst-images...
# extract https://dermnetnz.org/images/discoid-eczema-images...
# extract https://dermnetnz.org/image-catalogue/disease-relating-to-site-or-age-images...
# extract https://dermnetnz.org/topics/dry-skin-images...
# extract https://dermnetnz.org/topics/atypical-naevus-images...
# extract https://dermnetnz.org/topics/eccrine-poroma-images...
# extract https://dermnetnz.org/topics/ecthyma-images...
# extract https://dermnetnz.org/topics/eczema-herpeticum-images...
# extract https://dermnetnz.org/topics/ehlers-danlos-syndrome-images...
# extract https://dermnetnz.org/images/hand-foot-and-mouth-disease-images...
# extract https://dermnetnz.org/topics/epidermoid-and-trichilemmal-cyst-images...
# extract https://dermnetnz.org/topics/tuberous-sclerosis-images...
# extract https://dermnetnz.org/topics/tuberous-sclerosis-images...
# extract https://dermnetnz.org/topics/erythema-infectiosum-fifth-disease-images...
# extract https://dermnetnz.org/topics/erythema-migrans-images...
# extract https://dermnetnz.org/topics/erythema-multiforme-images...
# extract https://dermnetnz.org/topics/erythema-nodosum-images...
# extract https://dermnetnz.org/topics/erythrasma-images...
# extract https://dermnetnz.org/topics/erythroderma-images...
# extract https://dermnetnz.org/topics/extragenital-lichen-sclerosus-images...
# extract https://dermnetnz.org/topics/madarosis-images...
# extract https://dermnetnz.org/topics/madarosis-images...
# extract https://dermnetnz.org/topics/eyelid-dermatitis-images...
# extract https://dermnetnz.org/topics/angiokeratoma-images...
# extract https://dermnetnz.org/topics/acne-face-images...
# extract https://dermnetnz.org/topics/facial-psoriasis-images...
# extract https://dermnetnz.org/topics/fibrofolliculomas-in-birthoggdube-images...
# extract https://dermnetnz.org/topics/erythema-infectiosum-fifth-disease-images...
# extract https://dermnetnz.org/topics/atypical-mycobacterial-infection-images...
# extract https://dermnetnz.org/topics/flexural-psoriasis-images...
# extract https://dermnetnz.org/topics/folliculitis-images...
# extract https://dermnetnz.org/topics/folliculitis-keloidalis-images...
# extract https://dermnetnz.org/topics/angiokeratoma-images...
# extract https://dermnetnz.org/image-catalogue/fungal-skin-infection-images...
# extract https://dermnetnz.org/images/generalised-pustular-psoriasis-images...
# extract https://dermnetnz.org/topics/genital-crohn-disease-images...
# extract https://dermnetnz.org/topics/genital-herpes-images...
# extract https://dermnetnz.org/images/genital-lichen-planus-images...
# extract https://dermnetnz.org/topics/genital-psoriasis-images...
# extract https://dermnetnz.org/images/genital-wart-images...
# extract https://dermnetnz.org/topics/capillaritis-images...
# extract https://dermnetnz.org/topics/gouty-tophi-images...
# extract https://dermnetnz.org/topics/granular-parakeratosis-images...
# extract https://dermnetnz.org/topics/granuloma-annulare-images...
# extract https://dermnetnz.org/topics/transient-acantholytic-dermatosis-images...
# extract https://dermnetnz.org/topics/guttate-psoriasis-images...
# extract https://dermnetnz.org/image-catalogue/hair-scalp-nail-and-sweat-images...
# extract https://dermnetnz.org/topics/halo-mole-images...
# extract https://dermnetnz.org/topics/hand-dermatitis-images...
# extract https://dermnetnz.org/images/hand-foot-and-mouth-disease-images...
# extract https://dermnetnz.org/topics/herpes-simplex-images...
# extract https://dermnetnz.org/topics/herpes-zoster-images...
# extract https://dermnetnz.org/topics/hidradenitis-suppurativa-images...
# extract https://dermnetnz.org/topics/hidrocystoma-images...
# extract https://dermnetnz.org/images/amelanotic-melanoma-images...
# extract https://dermnetnz.org/topics/ichthyosis-images...
# extract https://dermnetnz.org/image-catalogue/immunological-disorder-images...
# extract https://dermnetnz.org/images/impetigo-images...
# extract https://dermnetnz.org/topics/intraepidermal-carcinoma-images...
# extract https://dermnetnz.org/topics/infantile-acne-images...
# extract https://dermnetnz.org/topics/infantile-papular-acrodermatitis-images...
# extract https://dermnetnz.org/topics/insect-bite-images...
# extract https://dermnetnz.org/image-catalogue/insect-mite-and-worm-bite-images...
# extract https://dermnetnz.org/topics/juvenile-plantar-dermatosis-images...
# extract https://dermnetnz.org/topics/kaposi-sarcoma-images...
# extract https://dermnetnz.org/images/keloid-and-hypertrophic-scar-images...
# extract https://dermnetnz.org/topics/keratoacanthoma-images...
# extract https://dermnetnz.org/topics/keratolytic-winter-erythema-images...
# extract https://dermnetnz.org/topics/keratosis-pilaris-images...
# extract https://dermnetnz.org/topics/kerion-images...
# extract https://dermnetnz.org/topics/labial-fusion-images...
# extract https://dermnetnz.org/topics...
# extract https://dermnetnz.org/topics/leg-ulcer-images...
# extract https://dermnetnz.org/...
# extract https://dermnetnz.org/topics/lentigo-images...
# extract https://dermnetnz.org/images/lentigo-maligna-melanoma-images...
# extract https://dermnetnz.org/image-catalogue/lesion-tumour-and-cancer-images...
# extract https://dermnetnz.org/topics/capillaritis-images...
# extract https://dermnetnz.org/images/lichen-planus-images...
# extract https://dermnetnz.org/images/nail-lichen-planus-images...
# extract https://dermnetnz.org/...
# extract https://dermnetnz.org/topics/lipodermatosclerosis-images...
# extract https://dermnetnz.org/topics/madarosis-images...
# extract https://dermnetnz.org/topics/madarosis-images...
# extract https://dermnetnz.org/topics/madarosis-images...
# extract https://dermnetnz.org/topics/capillaritis-images...
# extract https://dermnetnz.org/topics/mammary-and-extramammary-paget-disease-of-the-skin-images...
# extract https://dermnetnz.org/topics/measles-images...
# extract https://dermnetnz.org/images/melanoma-in-situ-images...
# extract https://dermnetnz.org/topics/melanoma-of-nail-unit-images...
# extract https://dermnetnz.org/topics/melanonychia-images...
# extract https://dermnetnz.org/topics/melasma-images...
# extract https://dermnetnz.org/topics/metastatic-melanoma-images...
# extract https://dermnetnz.org/topics/milia-images...
# extract https://dermnetnz.org/topics/mole-images...
# extract https://dermnetnz.org/topics/molluscum-contagiosum-images...
# extract https://dermnetnz.org/topics/candida-affecting-the-lips-mouth-and-face-images...
# extract https://dermnetnz.org/topics/morphoea-images...
# extract https://dermnetnz.org/topics/nail-psoriasis-images...
# extract https://dermnetnz.org/topics/necrotising-fasciitis-images...
# extract https://dermnetnz.org/topics/neurofibromatosis-images...
# extract https://dermnetnz.org/topics/nodular-bcc-images...
# extract https://dermnetnz.org/topics/nodular-bcc-images...
# extract https://dermnetnz.org/images/nodular-melanoma-images...
# extract https://dermnetnz.org/topics/atypical-mycobacterial-infection-images...
# extract https://dermnetnz.org/images/discoid-eczema-images...
# extract https://dermnetnz.org/topics/orf-images...
# extract https://dermnetnz.org/images/polymorphic-light-eruption-images...
# extract https://dermnetnz.org/topics/palmoplantar-psoriasis-images...
# extract https://dermnetnz.org/topics/palmoplantar-pustulosis-images...
# extract https://dermnetnz.org/topics/paronychia-images...
# extract https://dermnetnz.org/topics/patch-test-images...
# extract https://dermnetnz.org/images/pemphigus-vulgaris-images...
# extract https://dermnetnz.org/topics/penile-epithelial-neoplasia-images...
# extract https://dermnetnz.org/topics/balanitis-images...
# extract https://dermnetnz.org/images/genital-lichen-planus-images...
# extract https://dermnetnz.org/topics/penile-lichen-sclerosus-images...
# extract https://dermnetnz.org/topics/pearly-penile-papules-images...
# extract https://dermnetnz.org/topics/perianal-lichen-sclerosus-images...
# extract https://dermnetnz.org/images/periorificial-dermatitis-images...
# extract https://dermnetnz.org/images/angular-cheilitis-images...
# extract https://dermnetnz.org/images/angular-cheilitis-images...
# extract https://dermnetnz.org/image-catalogue/phototherapy-course-images...
# extract https://dermnetnz.org/topics/piezogenic-papule-images...
# extract https://dermnetnz.org/image-catalogue/pigmentation-problem-images...
# extract https://dermnetnz.org/topics/capillaritis-images...
# extract https://dermnetnz.org/topics/capillaritis-images...
# extract https://dermnetnz.org/images/pityrasis-alba-images...
# extract https://dermnetnz.org/...
# extract https://dermnetnz.org/topics/pityriasis-versicolor-images...
# extract https://dermnetnz.org/topics/plasma-cell-balanitisvulvitis-images...
# extract https://dermnetnz.org/images/polymorphic-light-eruption-images...
# extract https://dermnetnz.org/images/polymorphic-light-eruption-images...
# extract https://dermnetnz.org/images/dyshidrotic-eczema-images...
# extract https://dermnetnz.org/topics/pretibial-myxoedema-images...
# extract https://dermnetnz.org/image-catalogue/principals-of-dermatological-practice-course-images...
# extract https://dermnetnz.org/image-catalogue/procedures-images...
# extract https://dermnetnz.org/topics/prurigo-of-pregnancy-images...
# extract https://dermnetnz.org/topics/facial-psoriasis-images...
# extract https://dermnetnz.org/images/scalp-psoriasis-images...
# extract https://dermnetnz.org/topics/capillaritis-images...
# extract https://dermnetnz.org/topics/palmoplantar-pustulosis-images...
# extract https://dermnetnz.org/image-catalogue/reactions-to-external-agent-images...
# extract https://dermnetnz.org/topics/rhinophyma-images...
# extract https://dermnetnz.org/topics/basal-cell-carcinoma-affecting-the-ear-images...
# extract https://dermnetnz.org/topics/basal-cell-carcinoma-affecting-the-eyelid-images...
# extract https://dermnetnz.org/topics/basal-cell-carcinoma-affecting-the-face-images...
# extract https://dermnetnz.org/topics/basal-cell-carcinoma-affecting-the-nose-images...
# extract https://dermnetnz.org/topics/basal-cell-carcinoma-affecting-the-trunk-images...
# extract https://dermnetnz.org/images/rosacea-images...
# extract https://dermnetnz.org/topics/roseola-images...
# extract https://dermnetnz.org/topics/sjs-ten-images...
# extract https://dermnetnz.org/topics/systemic-lupus-erythematosus-images...
# extract https://dermnetnz.org/images/scabies-images...
# extract https://dermnetnz.org/topics/scalp-folliculitis-images...
# Error occurred for Scalp folliculitis images: Message: disconnected: unable to send message to renderer
#   (failed to check if window was closed: disconnected: not connected to DevTools)
#   (Session info: chrome-headless-shell=121.0.6167.140)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF672BB5E42+3538674]
# 	(No symbol) [0x00007FF6727D4C02]
# 	(No symbol) [0x00007FF672685AEB]
# 	(No symbol) [0x00007FF67267142B]
# 	(No symbol) [0x00007FF672671E5F]
# 	(No symbol) [0x00007FF672688CEB]
# 	(No symbol) [0x00007FF672689735]
# 	(No symbol) [0x00007FF67268D150]
# 	(No symbol) [0x00007FF67268D210]
# 	(No symbol) [0x00007FF6726CBBBC]
# 	(No symbol) [0x00007FF6726CC0CC]
# 	(No symbol) [0x00007FF67270E4A7]
# 	(No symbol) [0x00007FF6726EF0EF]
# 	(No symbol) [0x00007FF67270BDE3]
# 	(No symbol) [0x00007FF6726EEE53]
# 	(No symbol) [0x00007FF6726BF514]
# 	(No symbol) [0x00007FF6726C0631]
# 	GetHandleVerifier [0x00007FF672BE6CAD+3738973]
# 	GetHandleVerifier [0x00007FF672C3C506+4089270]
# 	GetHandleVerifier [0x00007FF672C34823+4057299]
# 	GetHandleVerifier [0x00007FF672905C49+720121]
# 	(No symbol) [0x00007FF6727E126F]
# 	(No symbol) [0x00007FF6727DC304]
# 	(No symbol) [0x00007FF6727DC432]
# 	(No symbol) [0x00007FF6727CBD04]
# 	BaseThreadInitThunk [0x00007FFFC963257D+29]
# 	RtlUserThreadStart [0x00007FFFCB48AA58+40]
#
# extract https://dermnetnz.org/image-catalogue/scaly-skin-disease-images...
# extract https://dermnetnz.org/topics/capillaritis-images...
# extract https://dermnetnz.org/topics/sebaceous-hyperplasia-images...
# extract https://dermnetnz.org/topics/seborrhoeic-keratosis-dermoscopy-images...
# extract https://dermnetnz.org/topics/seborrhoeic-keratosis-images...
# extract https://dermnetnz.org/topics/shiitake-flagellate-dermatitis-images...
# extract https://dermnetnz.org/image-catalogue/skin-pathology-images...
# extract https://dermnetnz.org/image-catalogue/skin-signs-of-systemic-disease-images...
# extract https://dermnetnz.org/topics/skin-tag-images...
# extract https://dermnetnz.org/topics/actinic-keratosis-face-images...
# extract https://dermnetnz.org/topics/actinic-keratosis-affecting-the-hand-images...
# extract https://dermnetnz.org/topics/actinic-keratosis-leg-and-foot-images...
# extract https://dermnetnz.org/topics/actinic-keratosis-scalp-images...
# extract https://dermnetnz.org/topics/actinic-keratosis-on-the-nose-images...
# extract https://dermnetnz.org/topics/actinic-keratosis-imiquimod-images...
# extract https://dermnetnz.org/topics/solar-lentigo-images...
# extract https://dermnetnz.org/topics/spa-pool-folliculitis-images...
# extract https://dermnetnz.org/topics/spider-telangiectasis-images...
# extract https://dermnetnz.org/topics/spider-telangiectasis-images...
# extract https://dermnetnz.org/topics/squamous-cell-carcinoma-of-limbs-images...
# extract https://dermnetnz.org/topics/squamous-cell-carcinoma-of-the-ear-images...
# extract https://dermnetnz.org/topics/squamous-cell-carcinoma-of-the-lip-images...
# extract https://dermnetnz.org/topics/squamous-cell-carcinoma-on-the-face-images...
# extract https://dermnetnz.org/images/staphylococcal-scalded-skin-syndrome-images...
# extract https://dermnetnz.org/topics/steroid-acne-images...
# extract https://dermnetnz.org/...
# extract https://dermnetnz.org/images/superficial-spreading-melanoma-images...
# extract https://dermnetnz.org/topics/supernumerary-nipple-images...
# extract https://dermnetnz.org/topics/syphilis-images...
# extract https://dermnetnz.org/topics/systemic-lupus-erythematosus-images...
# extract https://dermnetnz.org/topics/tinea-corporis-images...
# extract https://dermnetnz.org/topics/tinea-pedis-images...
# extract https://dermnetnz.org/topics/transient-acantholytic-dermatosis-images...
# extract https://dermnetnz.org/image-catalogue/treatment-images...
# extract https://dermnetnz.org/topics/trichotillomania-images...
# extract https://dermnetnz.org/topics/tuberous-sclerosis-images...
# extract https://dermnetnz.org/topics/ungual-squamous-cell-carcinoma-in-situ-images...
# extract https://dermnetnz.org/topics/urticaria-images...
# extract https://dermnetnz.org/topics/urticarial-vasculitis-images...
# extract https://dermnetnz.org/topics/varicella-images...
# extract https://dermnetnz.org/topics/vascular-malformation...
# extract https://dermnetnz.org/topics/vasculitis-images...
# extract https://dermnetnz.org/topics/venous-lake-images...
# extract https://dermnetnz.org/image-catalogue/viral-skin-infections...
# extract https://dermnetnz.org/topics/viral-warts-images...
# extract https://dermnetnz.org/images/vitiligo-images...
# extract https://dermnetnz.org/images/vulval-cancer-images...
# extract https://dermnetnz.org/images/vulval-erosive-lichen-planus-images...
# extract https://dermnetnz.org/topics/vulval-intraepithelial-neoplasia-images...
# extract https://dermnetnz.org/images/genital-lichen-planus-images...
# extract https://dermnetnz.org/topics/vulval-lichen-sclerosus-images...
# extract https://dermnetnz.org/topics/vulval-ulcer-images...
# extract https://dermnetnz.org/topics/vulvovaginal-candidiasis-images...
# extract https://dermnetnz.org/topics/xanthelasma-images...
# extract https://dermnetnz.org/topics/xeroderma-pigmentosum-images...

# %%
# create a dataframe from the image_disease list
dfs= pd.DataFrame({'disease_name': list_disease_name, 'image_url': image_disease}, columns=['disease_name', 'image_url'])
print(f'number of image: {len(dfs)}')

# Turning all the disease_name to lower case and dropping duplicates
dfs['disease_name'] = dfs['disease_name'].map(lambda x: x.lower())
Result= dfs.drop_duplicates('image_url', keep='first')
print(f'number of image after drop duplicate: {len(Result)}')

# save the result dataframe to a CSV 
Result.to_csv('Data/dermnetnz_Image.csv', index=False)
# Out:
# number of image: 14045
# number of image after drop duplicate: 9630
